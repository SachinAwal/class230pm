# %%
def avg():
    total = (total_obtained/total_marks) * 100
    return total
def grade():
    if percentage>=80:
        return "A"
    elif percentage>=60:
        return "B"
    elif percentage>=50:
        return "C"
    elif percentage>=40:
        return "D"
    else:
        return "Fail"

std_reprt = ""
noe = int(input("Enter no. of students = "))
for i in range(noe):
    name = input("Enter the name: ")
    physics_mrks = int(input("Enter the marks in physics: "))
    chemistry_mrks = int(input("Enter the marks in chemistry: "))
    maths_mrks = int(input("Enter the marks in maths: "))
    computer_mrks = int(input("Enter the marks in computer: "))
    total_obtained = physics_mrks + chemistry_mrks + maths_mrks + computer_mrks
    total_marks = 400
    percentage = avg()
    info = f"The student's name {name} has obtained {grade()} grade.\n"
    std_reprt += info
print("The result of the student are:\n",std_reprt)

mo = int(input("Enter 1 for search and 2 for replace: "))
if mo == 1: 
    if "A" in std_reprt:
        print("Distinction",std_reprt.count("A"))
    else:
        print("No")
elif mo == 2:
    data = input("Enter the data: ")    
    replace = input("Enter the replace data: ")
    final_data = std_reprt.replace(data, replace)
    print(final_data)
else:
    print("Finished")
# Out:
# Enter no. of students = 2
# Enter the name: sachi
# Enter the marks in physics: 95
# Enter the marks in chemistry: 85
# Enter the marks in maths: 75
# Enter the marks in computer: 65
# Enter the name: sank
# Enter the marks in physics: 65
# Enter the marks in chemistry: 98
# Enter the marks in maths: 45
# Enter the marks in computer: 55
# The result of the student are:
#  The student's name sachi has obtained A grade.
# The student's name sank has obtained B grade.
#
# Enter 1 for search and 2 for replace: 2
# Enter the data: sank
# Enter the data: sankar
# The student's name sachi has obtained A grade.
# The student's name sankar has obtained B grade.

# %%
def avgavg():
    student_grades = []

    for c in range(COLS):
        student = input("Enter the number of the student: ")
        grades = []

    for r in range (ROWS):
        grade = eval(input("Enter the grades for the student: "))
        grades.append(grade)
    student_grades[student] = grades
    print(grades)

error = "Non integer input. Try again>> " #Error message

def isfloat(value): #Functon to check if a number can be a grade
    try:
       float(value)
       return True
    except ValueError:
       return False

n = input("Enter number of students>> ") #Number of students
while not n.isdigit():
    n = input(error)

g = input("\nEnter number of grades per student>> ") #Number of Grades per student
while not g.isdigit():
    g = input(error)

grades = [] #The two dimensional list
print
#Receiving input from the user
for a in range(int(n)):
    temp = []
    print ("Student %i" % (a+1))
    for b in range(int(g)):
        grade = input("Grade %i>> " % (b+1))
        while not isfloat(grade):
            grade = input(error)
        temp.append(float(grade))
    grades.append(temp)
    print

students = [sum(stud)/float(len(stud)) for stud in grades]
#Returning output
print (students)
print (sum(students)/float(len(students)))
# Out:
# Enter number of students>> 2
#
# Enter number of grades per student>> 4
# Student 1
# Grade 1>> 66
# Grade 2>> 85
# Grade 3>> 89
# Grade 4>> 90
# Student 2
# Grade 1>> 56
# Grade 2>> 65
# Grade 3>> 70
# Grade 4>> 75
# [82.5, 66.5]
# 74.5

# %%
def avg():
    total = (total_obtained/total_marks) * 100
    return total
def grade():
    if percentage>=80:
        return "A"
    elif percentage>=60:
        return "B"
    elif percentage>=50:
        return "C"
    elif percentage>=40:
        return "D"
    else:
        return "Fail"

std_reprt = []
std = int(input("Enter the no. of students: "))
for i in range(1,std+1):
    name = input("Enter the name: ")
    physics = int(input("Enter the marks in physics: "))
    chemistry = int(input("Enter the marks in chemistry: "))
    maths = int(input("Enter the marks in maths: "))
    computer = int(input("Enter the marks in computer: "))
    total_obtained = physics + chemistry + maths + computer
    total_marks = 400
    percentage = avg()
    rslt = [[i, name, physics, chemistry, maths, computer,total_obtained,percentage,grade()]]
    std_reprt += rslt
print("The result of the student are:\n",std_reprt)

name = input("Enter the name for search: ").lower()
for j in std_reprt:
    if name in j[1].lower():
        j[1] = input("Enter the change value: ")
print(std_reprt)

name = input("Enter the name for search: ").lower()
for j in std_reprt:
    if name in j[1].lower():
        std_reprt.remove(j)
print(std_reprt)
# Out:
# Enter the no. of students: 2
# Enter the name: ram
# Enter the marks in physics: 90
# Enter the marks in chemistry: 95
# Enter the marks in maths: 80
# Enter the marks in computer: 85
# Enter the name: shyam
# Enter the marks in physics: 70
# Enter the marks in chemistry: 80
# Enter the marks in maths: 75
# Enter the marks in computer: 85
# The result of the student are:
#  [[1, 'ram', 90, 95, 80, 85, 350, 87.5, 'A'], [2, 'shyam', 70, 80, 75, 85, 310, 77.5, 'B']]
# Enter the name for search: ram
# Enter the change value: hari
# [[1, 'hari', 90, 95, 80, 85, 350, 87.5, 'A'], [2, 'shyam', 70, 80, 75, 85, 310, 77.5, 'B']]
# Enter the name for search: hari
# [[2, 'shyam', 70, 80, 75, 85, 310, 77.5, 'B']]
